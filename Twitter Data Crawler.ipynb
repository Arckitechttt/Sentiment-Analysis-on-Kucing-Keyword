# %% [markdown]
# # **How to Crawl Twitter Data More than 1500 Tweets**

# %% [markdown]
# ## **Node.JS Installation**

# %%
# Install Node.js (because tweet-harvest is built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %% [markdown]
# ## **Update NPM (Node Package Manager) to its Latest Version**

# %%
# !npm install -g npm@10.2.3
# Out:
# changed 14 packages in 4s
#
# 26 packages are looking for funding
#   run `npm fund` for details

# %% [markdown]
# ## **Crawl Twitter Data**

# %% [markdown]
# ### **Initialize Twitter Auth Token**

# %%
# Twitter Authentication Token
twt_auth_token = 'd5a16f58f17b3d26b6bf6374394ac7649603afb2'

# %% [markdown]
# ### **Start Crawling Twitter Data**

# %%
# Twitter Data Crawling using Tweet-Harvest v2.3.0
filename = 'jkw.csv'
keyword = 'jokowi lang:id'
limit = 1500

# !npx --yes tweet-harvest@2.3.0 -o "{filename}" -s "{keyword}" -l {limit} --token {twt_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 2s
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# ...

# %% [markdown]
# ## **Simple Data Understanding**

# %%
import pandas as pd

# Path to cats.csv
file_path = f"tweets-data/{filename}"

# cats.csv file reading using Pandas
ds = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
ds.head()
# Out:
#                        created_at               id_str  \
# 0  Sun Nov 12 07:56:17 +0000 2023  1723610653888577855
# 1  Sun Nov 12 07:56:14 +0000 2023  1723610642123522128
# 2  Sun Nov 12 07:56:09 +0000 2023  1723610618975174662
# 3  Sun Nov 12 07:56:06 +0000 2023  1723610605033341335
# 4  Sun Nov 12 07:55:57 +0000 2023  1723610569373290769
#
#                                            full_text  quote_count  \
# 0  @jokowi Semoga lawatan kenegaraan ini dapat me...            0
# 1  Pengelolaan Satu Data Di Jateng Mampu Membangu...            0
# 2  Jokowi ke AS Bertemu Biden, Bawa Misi Perdamai...            0
# 3  Jokowi Terbitkan Aturan Pengupahan Baru, Pengu...            0
# 4  @ceritamedan @indoviral8 seriusan 2.5 M nder??...            0
#
#    reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0            0              0               0   in             89169305
# 1            0              0               0   in  1534729852024020992
# ...

# %%
# Check number of columns and rows of the DataFrame
ukuran_dataset = ds.shape
print(f"Jumlah baris dari DataFrame adalah {ukuran_dataset[0]}.")
print(f"Jumlah kolom dari DataFrame adalah {ukuran_dataset[1]}.")
# Out:
# Jumlah baris dari DataFrame adalah 1511.
# Jumlah kolom dari DataFrame adalah 12.

# %%
# Column names in the DataFrame
list(ds.columns)
# Out:
# ['created_at',
#  'id_str',
#  'full_text',
#  'quote_count',
#  'reply_count',
#  'retweet_count',
#  'favorite_count',
#  'lang',
#  'user_id_str',
#  'conversation_id_str',
#  'username',
#  'tweet_url']
